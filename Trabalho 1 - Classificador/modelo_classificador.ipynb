# %% [markdown]
# # Problema de Classificação

# %% [markdown]
# ## Introdução

# %% [markdown]
# O problema tem como objetivo desenvolver um classificador que auxilie na aprovação de crédito. Desta forma, é possível identificar entre os clientes que atendam aos pré-requisitos básicos, aqueles que possuem alto risco de inadimplência ao solicitar produtos de crédito ou empréstimo pessoal. Essa análise será realizada através dos dados históricos de 20000 de antigos pagadores, com os quais preveremos se os 5000 novos serão ou não bons pagadores.

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Compreensão do dados

# %% [markdown]
# ### Descrição dos Dados

# %%
excel_file_path = '.\data\dicionario_de_dados.xlsx'
features = pd.read_excel(excel_file_path)

features
# Out:
#     Coluna                  Nome da Variável  \
# 0        0                    id_solicitante
# 1        1                produto_solicitado
# 2        2                    dia_vencimento
# 3        3           forma_envio_solicitacao
# 4        4                     tipo_endereco
# 5        5                              sexo
# 6        6                             idade
# 7        7                      estado_civil
# 8        8                  qtde_dependentes
# 9        9                    grau_instrucao
# 10      10                     nacionalidade
# 11      11                estado_onde_nasceu
# 12      12                estado_onde_reside
# 13      13       possui_telefone_residencial
# 14      14  codigo_area_telefone_residencial
# 15      15                   tipo_residencia
# 16      16               meses_na_residencia
# 17      17           possui_telefone_celular
# 18      18                      possui_email
# 19      19              renda_mensal_regular
# 20      20                       renda_extra
# 21      21                possui_cartao_visa
# 22      22          possui_cartao_mastercard
# 23      23              possui_cartao_diners
# 24      24                possui_cartao_amex
# 25      25             possui_outros_cartoes
# 26      26             qtde_contas_bancarias
# 27      27   qtde_contas_bancarias_especiais
# 28      28          valor_patrimonio_pessoal
# 29      29                      possui_carro
# 30      30        vinculo_formal_com_empresa
# 31      31              estado_onde_trabalha
# 32      32          possui_telefone_trabalho
# 33      33     codigo_area_telefone_trabalho
# 34      34                 meses_no_trabalho
# 35      35                         profissao
# 36      36                          ocupacao
# 37      37             profissao_companheiro
# 38      38        grau_instrucao_companheiro
# 39      39                 local_onde_reside
# 40      40               local_onde_trabalha
# 41      41                      inadimplente
#
#                                             Descrição  \
# 0   número sequencial de identificação do solicitante
# 1   produto solicitado (cartão de crédito, emprést...
# 2   dia_do_vencimento da fatura do cartão ou das p...
# 3   forma de envio da solicitação de crédito (inte...
# 4   tipo de endereço para correspondência informad...
# 5                                 sexo do solicitante
# 6        idade do solicitante na época da solicitação
# 7                         estado civil do solicitante
# 8   quantidade de dependentes informada pelo solic...
# 9   grau de instrução do solicitante, numa escala ...
# 10  nacionalidade do solicitante (estrangeiro/bras...
# 11  estado onde o solicitante nasceu ou se natural...
# 12                   estado onde o solicitante reside
# 13  indica se o solicitante possui telefone reside...
# 14  pseudocódigo identificador de área do telefone...
# 15  tipo de residência do solicitante (própria, fi...
# 16  tempo em que reside no endereço informado, em ...
# 17    indica se o solicitante possui telefone celular
# 18              indica se o solicitante possui e-mail
# 19                renda mensal regular do solicitante
# 20         renda mensal extra/eventual do solicitante
# 21         indica se o solicitante possui cartão VISA
# 22   indica se o solicitante possui cartão MASTERCARD
# 23       indica se o solicitante possui cartão DINERS
# 24         indica se o solicitante possui cartão AMEX
# 25  indica se o solicitante possui outros cartões ...
# 26  indica a quantidade de contas bancárias que o ...
# 27  indica a quantidade de contas bancárias especi...
# 28  valor total dos bens móveis e imóveis em nome ...
# 29   indica se o solicitante possui automóvel próprio
# 30  indica se o solicitante comprovou vínculo form...
# 31                 estado onde o solicitante trabalha
# 32  indica se o solicitante possui telefone profis...
# 33  pseudocódigo identificador de área do telefone...
# 34  tempo em que trabalha no local informado, em m...
# 35                           profissão do solicitante
# 36  ocupação do solicitante (funcionário de empres...
# 37  profissão do cônjuge ou companheiro do solicit...
# 38  grau de instrução do cônjuge ou companheiro do...
# 39  código do local onde o solicitante reside (3 d...
# 40  código do local onde o solicitante trabalha (3...
# 41            variável-alvo a ser predita pelo modelo
#
#                                              Conteúdo  \
# 0                                             1-20000
# 1                            código numérico 1,2 ou 7
# 2                                     1,5,10,15,20,25
# 3                       internet, correio, presencial
# 4                          1 = residencial, 2 = outro
# 5      M = masculino, F = feminino, N = não informado
# 6                                                 NaN
# 7         0,1,2,3,4,5,6,7 (codificação não informada)
# 8                              valor numérico inteiro
# 9                                         0,1,2,3,4,5
# 10  0 = estrangeiro, 1 = brasileiro, 2 = naturalizado
# 11                      siglas de estados brasileiros
# 12                      siglas de estados brasileiros
# 13                                   Y = sim, N = não
# 14                                    código numérico
# 15                                        0,1,2,3,4,5
# 16                             valor numérico inteiro
# 17                                   Y = sim, N = não
# 18                         0 = não possui, 1 = possui
# 19                          valor financeiro em reais
# 20                          valor financeiro em reais
# 21                         0 = não possui, 1 = possui
# 22                         0 = não possui, 1 = possui
# 23                         0 = não possui, 1 = possui
# 24                         0 = não possui, 1 = possui
# 25                         0 = não possui, 1 = possui
# 26                             valor numérico inteiro
# 27                             valor numérico inteiro
# 28                          valor financeiro em reais
# 29                         0 = não possui, 1 = possui
# 30                                   Y = sim, N = não
# 31                      siglas de estados brasileiros
# 32                                   Y = sim, N = não
# 33                                    código numérico
# 34                             valor numérico inteiro
# 35                          código numérico de 0 a 18
# 36                           código numérico de 0 a 5
# 37                          código numérico de 0 a 18
# 38                                        0,1,2,3,4,5
# 39                       código numérico de 3 dígitos
# 40                       código numérico de 3 dígitos
# 41                  0 = bom pagador, 1 = inadimplente
#
#                                           Observações
# 0   1-20000 no conjunto de treinamento e 20001-250...
# 1   O significado dos códigos não foi informado pe...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Há registros com esse campo vazio. Sugiro pree...
# 6                                                 NaN
# 7   O significado dos códigos não foi informado pe...
# 8                                                 NaN
# 9   Por possível falha na extração, esta coluna ve...
# 10                                                NaN
# 11  Em alguns registros este campo está vazio ou p...
# 12                                                NaN
# 13                                                NaN
# 14  O significado dos códigos não foi informado pe...
# 15  O significado dos códigos não foi informado pe...
# 16                                                NaN
# 17  Por possível falha na extração, esta coluna ve...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Conteúdo aparentemente idêntico ao campo anter...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Existem registros não preenchidos, mesmo quand...
# 32                                                NaN
# 33  O significado dos códigos não foi informado pe...
# 34  Vasta maioria com valor zero, mesmo quando o s...
# 35  O significado dos códigos não foi informado pe...
# 36  O significado dos códigos não foi informado pe...
# 37  O significado dos códigos não foi informado pe...
# 38              Existem registros preechidos com NULL
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN

# %% [markdown]
# ### Carregamento dos Dados

# %%
df_train = pd.read_csv(".\data\conjunto_de_treinamento.csv")

# Carregando conjunto de teste
df_test = pd.read_csv(".\data\conjunto_de_teste.csv")

# %% [markdown]
# #### Visuando cabeçalho do dataframe de treino

# %%
df_train.head()
# Out:
#    id_solicitante  produto_solicitado  dia_vencimento forma_envio_solicitacao  \
# 0               1                   1              10              presencial
# 1               2                   1              25                internet
# 2               3                   1              20                internet
# 3               4                   1              20                internet
# 4               5                   7               1                internet
#
#    tipo_endereco sexo  idade  estado_civil  qtde_dependentes  grau_instrucao  \
# 0              1    M     85             2                 0               0
# 1              1    F     38             1                 0               0
# 2              1    F     37             2                 0               0
# 3              1    M     37             1                 1               0
# 4              1    F     51             1                 3               0
#
#    ...  possui_telefone_trabalho codigo_area_telefone_trabalho  \
# 0  ...                         N
# 1  ...                         N
# 2  ...                         N
# 3  ...                         Y                            54
# 4  ...                         N
#
#   meses_no_trabalho profissao ocupacao  profissao_companheiro  \
# 0                 0       9.0      1.0                    0.0
# 1                 0       2.0      5.0                    NaN
# 2                 0       NaN      NaN                    NaN
# 3                 0       9.0      2.0                    NaN
# 4                 0       9.0      5.0                    NaN
#
#    grau_instrucao_companheiro local_onde_reside  local_onde_trabalha  \
# 0                         0.0             600.0                600.0
# 1                         NaN             492.0                492.0
# 2                         NaN             450.0                450.0
# 3                         NaN             932.0                932.0
# 4                         NaN             440.0                440.0
#
#    inadimplente
# 0             0
# 1             0
# 2             1
# 3             1
# 4             1
#
# [5 rows x 42 columns]

# %% [markdown]
# #### Descrição dos dados de treino

# %%
dict_type_features = {'Nome da Feature': df_train.columns, 'Tipo': df_train.dtypes.astype(str).tolist()}

info_colunas = pd.DataFrame(dict_type_features).reset_index(drop=True)
info_colunas
# Out:
#                      Nome da Feature     Tipo
# 0                     id_solicitante    int64
# 1                 produto_solicitado    int64
# 2                     dia_vencimento    int64
# 3            forma_envio_solicitacao   object
# 4                      tipo_endereco    int64
# 5                               sexo   object
# 6                              idade    int64
# 7                       estado_civil    int64
# 8                   qtde_dependentes    int64
# 9                     grau_instrucao    int64
# 10                     nacionalidade    int64
# 11                estado_onde_nasceu   object
# 12                estado_onde_reside   object
# 13       possui_telefone_residencial   object
# 14  codigo_area_telefone_residencial   object
# 15                   tipo_residencia  float64
# 16               meses_na_residencia  float64
# 17           possui_telefone_celular   object
# 18                      possui_email    int64
# 19              renda_mensal_regular  float64
# 20                       renda_extra  float64
# 21                possui_cartao_visa    int64
# 22          possui_cartao_mastercard    int64
# 23              possui_cartao_diners    int64
# 24                possui_cartao_amex    int64
# 25             possui_outros_cartoes    int64
# 26             qtde_contas_bancarias    int64
# 27   qtde_contas_bancarias_especiais    int64
# 28          valor_patrimonio_pessoal  float64
# 29                      possui_carro    int64
# 30        vinculo_formal_com_empresa   object
# 31              estado_onde_trabalha   object
# 32          possui_telefone_trabalho   object
# 33     codigo_area_telefone_trabalho   object
# 34                 meses_no_trabalho    int64
# 35                         profissao  float64
# 36                          ocupacao  float64
# 37             profissao_companheiro  float64
# 38        grau_instrucao_companheiro  float64
# 39                 local_onde_reside  float64
# 40               local_onde_trabalha  float64
# 41                      inadimplente    int64

# %% [markdown]
# #### Listando variáveis categóricas

# %%
# Inicializar listas vazias para cada tipo diferente
tipos_diferentes = set(dict_type_features["Tipo"])
listas_por_tipo = {tipo: [] for tipo in tipos_diferentes}

# Organizar os dados nas listas apropriadas
for nome, tipo in zip(dict_type_features["Nome da Feature"], dict_type_features["Tipo"]):
    listas_por_tipo[tipo].append(nome)

listas_por_tipo['object']
# Out:
# ['forma_envio_solicitacao',
#  'sexo',
#  'estado_onde_nasceu',
#  'estado_onde_reside',
#  'possui_telefone_residencial',
#  'codigo_area_telefone_residencial',
#  'possui_telefone_celular',
#  'vinculo_formal_com_empresa',
#  'estado_onde_trabalha',
#  'possui_telefone_trabalho',
#  'codigo_area_telefone_trabalho']

# %% [markdown]
# #### Descrevendo variáveis numéricas

# %%
df_train_features_numericals = df_train[listas_por_tipo['float64']] + df_train[listas_por_tipo['int64']]
df_train.describe()
# Out:
#        id_solicitante  produto_solicitado  dia_vencimento  tipo_endereco  \
# count    20000.000000        20000.000000    20000.000000   20000.000000
# mean     10000.500000            1.284350       13.147250       1.006350
# std       5773.647028            1.008239        6.748507       0.079435
# min          1.000000            1.000000        1.000000       1.000000
# 25%       5000.750000            1.000000       10.000000       1.000000
# 50%      10000.500000            1.000000       10.000000       1.000000
# 75%      15000.250000            1.000000       20.000000       1.000000
# max      20000.000000            7.000000       25.000000       2.000000
#
#               idade  estado_civil  qtde_dependentes  grau_instrucao  \
# count  20000.000000  20000.000000      20000.000000         20000.0
# mean      42.352500      2.120850          0.666400             0.0
# std       14.930177      1.332004          1.236725             0.0
# min        7.000000      0.000000          0.000000             0.0
# 25%       31.000000      1.000000          0.000000             0.0
# 50%       40.000000      2.000000          0.000000             0.0
# 75%       52.000000      2.000000          1.000000             0.0
# max      106.000000      7.000000         53.000000             0.0
#
#        nacionalidade  tipo_residencia  ...  valor_patrimonio_pessoal  \
# count   20000.000000     19464.000000  ...              2.000000e+04
# mean        0.961600         1.261303  ...              2.095614e+03
# std         0.202305         0.883580  ...              4.403344e+04
# min         0.000000         0.000000  ...              0.000000e+00
# 25%         1.000000         1.000000  ...              0.000000e+00
# 50%         1.000000         1.000000  ...              0.000000e+00
# 75%         1.000000         1.000000  ...              0.000000e+00
# max         2.000000         5.000000  ...              6.000000e+06
#
#        possui_carro  meses_no_trabalho     profissao      ocupacao  \
# count  20000.000000       20000.000000  16903.000000  17022.000000
# mean       0.339050           0.008900      8.045081      2.533310
# std        0.473399           0.388881      3.210790      1.532765
# min        0.000000           0.000000      0.000000      0.000000
# 25%        0.000000           0.000000      9.000000      1.000000
# 50%        0.000000           0.000000      9.000000      2.000000
# 75%        1.000000           0.000000      9.000000      4.000000
# max        1.000000          32.000000     17.000000      5.000000
#
#        profissao_companheiro  grau_instrucao_companheiro  local_onde_reside  \
# count            8486.000000                 7140.000000       20000.000000
# mean                3.708107                    0.288095         581.295250
# std                 5.181241                    0.944339         227.369798
# min                 0.000000                    0.000000         105.000000
# 25%                 0.000000                    0.000000         444.000000
# 50%                 0.000000                    0.000000         596.000000
# 75%                11.000000                    0.000000         728.000000
# max                17.000000                    5.000000         999.000000
#
#        local_onde_trabalha  inadimplente
# count         20000.000000  20000.000000
# mean            581.295250      0.500000
# std             227.369798      0.500013
# min             105.000000      0.000000
# 25%             444.000000      0.000000
# 50%             596.000000      0.500000
# 75%             728.000000      1.000000
# max             999.000000      1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Tratamento de Dados Faltantes

# %% [markdown]
# - Verificando quantidade de dados faltantes

# %%
# Substitua todos os campos vazios por NaN
df_train.replace('', np.nan, inplace=True)
df_train.replace(' ', np.nan, inplace=True)
df_train
# Out:
#        id_solicitante  produto_solicitado  dia_vencimento  \
# 0                   1                   1              10
# 1                   2                   1              25
# 2                   3                   1              20
# 3                   4                   1              20
# 4                   5                   7               1
# ...               ...                 ...             ...
# 19995           19996                   1              10
# 19996           19997                   1              20
# 19997           19998                   1              10
# 19998           19999                   1               5
# 19999           20000                   2              20
#
#       forma_envio_solicitacao  tipo_endereco sexo  idade  estado_civil  \
# 0                  presencial              1    M     85             2
# 1                    internet              1    F     38             1
# 2                    internet              1    F     37             2
# 3                    internet              1    M     37             1
# 4                    internet              1    F     51             1
# ...                       ...            ...  ...    ...           ...
# 19995              presencial              1    M     27             2
# 19996              presencial              1    F     26             2
# 19997                internet              1    F     63             2
# 19998                internet              1    F     84             1
# 19999              presencial              1    F     53             1
#
#        qtde_dependentes  grau_instrucao  ...  possui_telefone_trabalho  \
# 0                     0               0  ...                         N
# 1                     0               0  ...                         N
# 2                     0               0  ...                         N
# 3                     1               0  ...                         Y
# 4                     3               0  ...                         N
# ...                 ...             ...  ...                       ...
# 19995                 0               0  ...                         N
# 19996                 1               0  ...                         N
# 19997                 0               0  ...                         N
# 19998                 0               0  ...                         N
# 19999                 0               0  ...                         N
#
#       codigo_area_telefone_trabalho meses_no_trabalho profissao ocupacao  \
# 0                               NaN                 0       9.0      1.0
# 1                               NaN                 0       2.0      5.0
# 2                               NaN                 0       NaN      NaN
# 3                                54                 0       9.0      2.0
# 4                               NaN                 0       9.0      5.0
# ...                             ...               ...       ...      ...
# 19995                           NaN                 0       9.0      1.0
# 19996                           NaN                 0       9.0      2.0
# 19997                           NaN                 0       9.0      1.0
# 19998                           NaN                 0       NaN      NaN
# 19999                           NaN                 0       9.0      5.0
#
#        profissao_companheiro  grau_instrucao_companheiro local_onde_reside  \
# 0                        0.0                         0.0             600.0
# 1                        NaN                         NaN             492.0
# 2                        NaN                         NaN             450.0
# 3                        NaN                         NaN             932.0
# 4                        NaN                         NaN             440.0
# ...                      ...                         ...               ...
# 19995                    0.0                         0.0             308.0
# 19996                    0.0                         0.0             639.0
# 19997                    NaN                         NaN             486.0
# 19998                    NaN                         NaN             590.0
# 19999                    0.0                         0.0             132.0
#
#        local_onde_trabalha  inadimplente
# 0                    600.0             0
# 1                    492.0             0
# 2                    450.0             1
# 3                    932.0             1
# 4                    440.0             1
# ...                    ...           ...
# 19995                308.0             0
# 19996                639.0             0
# 19997                486.0             0
# 19998                590.0             0
# 19999                132.0             0
#
# [20000 rows x 42 columns]

# %%
tabela_dados_faltantes = df_train.isnull().sum().reset_index()
tabela_dados_faltantes.columns = ['Feature', 'Dados Faltantes']
tabela_dados_faltantes
# Out:
#                              Feature  Dados Faltantes
# 0                     id_solicitante                0
# 1                 produto_solicitado                0
# 2                     dia_vencimento                0
# 3            forma_envio_solicitacao                0
# 4                      tipo_endereco                0
# 5                               sexo                7
# 6                              idade                0
# 7                       estado_civil                0
# 8                   qtde_dependentes                0
# 9                     grau_instrucao                0
# 10                     nacionalidade                0
# 11                estado_onde_nasceu              822
# 12                estado_onde_reside                0
# 13       possui_telefone_residencial                0
# 14  codigo_area_telefone_residencial             3534
# 15                   tipo_residencia              536
# 16               meses_na_residencia             1450
# 17           possui_telefone_celular                0
# 18                      possui_email                0
# 19              renda_mensal_regular                0
# 20                       renda_extra                0
# 21                possui_cartao_visa                0
# 22          possui_cartao_mastercard                0
# 23              possui_cartao_diners                0
# 24                possui_cartao_amex                0
# 25             possui_outros_cartoes                0
# 26             qtde_contas_bancarias                0
# 27   qtde_contas_bancarias_especiais                0
# 28          valor_patrimonio_pessoal                0
# 29                      possui_carro                0
# 30        vinculo_formal_com_empresa                0
# 31              estado_onde_trabalha            13573
# 32          possui_telefone_trabalho                0
# 33     codigo_area_telefone_trabalho            14525
# 34                 meses_no_trabalho                0
# 35                         profissao             3097
# 36                          ocupacao             2978
# 37             profissao_companheiro            11514
# 38        grau_instrucao_companheiro            12860
# 39                 local_onde_reside                0
# 40               local_onde_trabalha                0
# 41                      inadimplente                0

# %%
#treino
df_train['sexo'] = df_train['sexo'].str.replace(' ','N') #substitiur vazios por N
df_train['estado_onde_reside'] = df_train['sexo'].str.replace(' ','XX') #substitiur vazios por XX

#teste
df_test['sexo'] = df_test['sexo'].str.replace(' ','N') #substitiur vazios por N
df_test['estado_onde_reside'] = df_test['sexo'].str.replace(' ','XX') #substitiur vazios por XX

# %% [markdown]
# - Colunas com grande quantidade de dados faltantes serão removidas: grau_instrucao_companheiro, profissao_companheiro, estado_onde_trabalha, codigo_area_telefone_trabalho

# %%
df_train = df_train.drop('grau_instrucao_companheiro', axis=1)
df_train = df_train.drop('profissao_companheiro', axis=1)
df_train = df_train.drop('estado_onde_trabalha', axis=1)
df_train = df_train.drop('codigo_area_telefone_trabalho', axis=1)


df_test = df_test.drop('grau_instrucao_companheiro', axis=1)
df_test = df_test.drop('profissao_companheiro', axis=1)
df_test = df_test.drop('estado_onde_trabalha', axis=1)
df_test = df_test.drop('codigo_area_telefone_trabalho', axis=1)

# %% [markdown]
# ### Análise Exploratória de Dados

# %% [markdown]
# #### Colunas do dataframe

# %%
df_train.columns
# Out:
# Index(['id_solicitante', 'produto_solicitado', 'dia_vencimento',
#        'forma_envio_solicitacao', 'tipo_endereco', 'sexo', 'idade',
#        'estado_civil', 'qtde_dependentes', 'grau_instrucao', 'nacionalidade',
#        'estado_onde_nasceu', 'estado_onde_reside',
#        'possui_telefone_residencial', 'codigo_area_telefone_residencial',
#        'tipo_residencia', 'meses_na_residencia', 'possui_telefone_celular',
#        'possui_email', 'renda_mensal_regular', 'renda_extra',
#        'possui_cartao_visa', 'possui_cartao_mastercard',
#        'possui_cartao_diners', 'possui_cartao_amex', 'possui_outros_cartoes',
#        'qtde_contas_bancarias', 'qtde_contas_bancarias_especiais',
#        'valor_patrimonio_pessoal', 'possui_carro',
#        'vinculo_formal_com_empresa', 'possui_telefone_trabalho',
#        'meses_no_trabalho', 'profissao', 'ocupacao', 'local_onde_reside',
#        'local_onde_trabalha', 'inadimplente'],
#       dtype='object')

# %% [markdown]
# #### Matriz de dispersão

# %%
''' # Subconjunto do DataFrame contendo apenas as colunas mencionadas
selected_columns = ['tipo_endereco', 'idade','qtde_dependentes', 'grau_instrucao','renda_mensal_regular', 'renda_extra', 'meses_no_trabalho', 'inadimplente']
df_subset = df_train[selected_columns]

sns.pairplot(df_subset)
plt.show() '''
# Out:
# " # Subconjunto do DataFrame contendo apenas as colunas mencionadas\nselected_columns = ['tipo_endereco', 'idade','qtde_dependentes', 'grau_instrucao','renda_mensal_regular', 'renda_extra', 'meses_no_trabalho', 'inadimplente']\ndf_subset = df_train[selected_columns]\n\nsns.pairplot(df_subset)\nplt.show() "

# %% [markdown]
# ## Pré-processamento de Dados

# %% [markdown]
# ### Codificação de variáveis categóricas
#
# - Features Categóricas

# %%
''' ['forma_envio_solicitacao',
 'sexo',
 'estado_onde_nasceu',
 'estado_onde_reside',
 'possui_telefone_residencial',
 'codigo_area_telefone_residencial',
 'possui_telefone_celular',
 'vinculo_formal_com_empresa',
 'estado_onde_trabalha',
 'possui_telefone_trabalho',
 'codigo_area_telefone_trabalho']
 '''
# Out:
# " ['forma_envio_solicitacao',\n 'sexo',\n 'estado_onde_nasceu',\n 'estado_onde_reside',\n 'possui_telefone_residencial',\n 'codigo_area_telefone_residencial',\n 'possui_telefone_celular',\n 'vinculo_formal_com_empresa',\n 'estado_onde_trabalha',\n 'possui_telefone_trabalho',\n 'codigo_area_telefone_trabalho']\n "

# %% [markdown]
# - One-Hot Encoding: Features com mais de duas categorias que não tenham

# %%
# produto_solicitado -> #1, #2, #3, #4, #5, #6, #7
# forma_envio_solicitacao ->  #correio, internet, presencial
# sexo -> #F, M e N


df_train = pd.get_dummies(df_train,columns=['produto_solicitado', 
                                            'forma_envio_solicitacao',
                                            'sexo']) 

df_test = pd.get_dummies(df_test,columns=['produto_solicitado', 
                                            'forma_envio_solicitacao',
                                            'sexo'])

# %% [markdown]
# - Label Binarizer: Converte rótulos em inteiros, não tendo ordem nominal entre os valores da feature

# %%
def binarizador(colunas_a_binarizar, dataframe):
    binarizador = LabelBinarizer()
    for feature in colunas_a_binarizar:
        dataframe[feature] = binarizador.fit_transform(dataframe[feature])

    return dataframe

# %%
# possui_telefone_residencial -> #Y, N
# vinculo_formal_com_empresa ->  #Y, N
# possui_telefone_trabalho -> #Y, N

colunas_a_binarizar = ['possui_telefone_residencial', 'vinculo_formal_com_empresa', 'possui_telefone_trabalho']

df_train = binarizador(colunas_a_binarizar, df_train)
df_test = binarizador(colunas_a_binarizar, df_test)

# %% [markdown]
# ### Dropando Features

# %% [markdown]
# - grau_instrucao_companheiro, profissao_companheiro, estado_onde_trabalha e codigo_area_telefone_trabalho foram removidas, pois tinham uma grande quantidade de dados faltantes
# - possui_telefone_celular tem valor N para todos os dados, sendo removido também
# - estado_onde_nasceu e estado_onde_reside serão removidas por serem features categoricas não codificadas

# %%
df_train = df_train.drop('possui_telefone_celular', axis=1)
df_train = df_train.drop('estado_onde_nasceu', axis=1)
df_train = df_train.drop('estado_onde_reside', axis=1)


df_test = df_test.drop('possui_telefone_celular', axis=1)
df_test = df_test.drop('estado_onde_nasceu', axis=1)
df_test = df_test.drop('estado_onde_reside', axis=1)

# %% [markdown]
# ### Substindo NaN pela média

# %% [markdown]
# - A feature meses_na_residencia pode ter seus valores NaN substituídos pelas média da mesma

# %%
# Calcula a média da feature
mean = df_train["meses_na_residencia"].mean()

# Substitui os NaN pela média da feature
df_train["meses_na_residencia"] = df_train["meses_na_residencia"].fillna(mean)


# Calcula a média da feature
mean = df_test["meses_na_residencia"].mean()

# Substitui os NaN pela média da feature
df_test["meses_na_residencia"] = df_test["meses_na_residencia"].fillna(mean)

# %% [markdown]
# ## Modelagem

# %% [markdown]
# ### Seleção de Features

# %% [markdown]
# #### Removemos as features que não são de interesse ou não parecem ter muita correlação pelas análises

# %%
df_train.columns
# Out:
# Index(['id_solicitante', 'dia_vencimento', 'tipo_endereco', 'idade',
#        'estado_civil', 'qtde_dependentes', 'grau_instrucao', 'nacionalidade',
#        'possui_telefone_residencial', 'codigo_area_telefone_residencial',
#        'tipo_residencia', 'meses_na_residencia', 'possui_email',
#        'renda_mensal_regular', 'renda_extra', 'possui_cartao_visa',
#        'possui_cartao_mastercard', 'possui_cartao_diners',
#        'possui_cartao_amex', 'possui_outros_cartoes', 'qtde_contas_bancarias',
#        'qtde_contas_bancarias_especiais', 'valor_patrimonio_pessoal',
#        'possui_carro', 'vinculo_formal_com_empresa',
#        'possui_telefone_trabalho', 'meses_no_trabalho', 'profissao',
#        'ocupacao', 'local_onde_reside', 'local_onde_trabalha', 'inadimplente',
#        'produto_solicitado_1', 'produto_solicitado_2', 'produto_solicitado_7',
#        'forma_envio_solicitacao_correio', 'forma_envio_solicitacao_internet',
#        'forma_envio_solicitacao_presencial', 'sexo_F', 'sexo_M', 'sexo_N'],
#       dtype='object')

# %%
#colunas selecionas

colunas_selecionadas = df_train.columns.tolist()
colunas_selecionadas.remove('id_solicitante')  #removida pois é o id
colunas_selecionadas.remove('inadimplente') # removida pois é o target

colunas_selecionadas.remove('codigo_area_telefone_residencial') #removidas por ter dados NaN não tratados
colunas_selecionadas.remove('tipo_residencia') #removidas por ter dados NaN não tratados
colunas_selecionadas.remove('profissao') #removidas por ter dados NaN não tratados
colunas_selecionadas.remove('ocupacao') #removidas por ter dados NaN não tratados


colunas_selecionadas
# Out:
# ['dia_vencimento',
#  'tipo_endereco',
#  'idade',
#  'estado_civil',
#  'qtde_dependentes',
#  'grau_instrucao',
#  'nacionalidade',
#  'possui_telefone_residencial',
#  'meses_na_residencia',
#  'possui_email',
#  'renda_mensal_regular',
#  'renda_extra',
#  'possui_cartao_visa',
#  'possui_cartao_mastercard',
#  'possui_cartao_diners',
#  'possui_cartao_amex',
#  'possui_outros_cartoes',
#  'qtde_contas_bancarias',
#  'qtde_contas_bancarias_especiais',
#  'valor_patrimonio_pessoal',
#  'possui_carro',
#  'vinculo_formal_com_empresa',
#  'possui_telefone_trabalho',
#  'meses_no_trabalho',
#  'local_onde_reside',
#  'local_onde_trabalha',
#  'produto_solicitado_1',
#  'produto_solicitado_2',
#  'produto_solicitado_7',
#  'forma_envio_solicitacao_correio',
#  'forma_envio_solicitacao_internet',
#  'forma_envio_solicitacao_presencial',
#  'sexo_F',
#  'sexo_M',
#  'sexo_N']

# %% [markdown]
# ### Escolha do Modelo

# %% [markdown]
# #### Definindo conjuntos de teste e treino

# %%
# selecionando colunas

X_train = df_train[colunas_selecionadas].iloc[:,:].values #pega todas as colunas selecionadas
y_train = df_train["inadimplente"].iloc[:,].values #pega somente a coluna inadimplente

# conjunto de teste (5000) sem target

X_test_output = df_test[colunas_selecionadas].iloc[:,:].values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_train, 
    y_train.ravel(),
    train_size=0.8,
    shuffle=True,
    random_state=777
    )

# %% [markdown]
# - Verificando se há dados faltantes

# %%
# Calculando a soma de dados faltantes em cada coluna
soma_dados_faltantes = np.isnan(X_train).sum(axis=0)

# Criando uma tabela com os resultados
tabela_dados_faltantes = np.vstack((np.arange(X_train.shape[1]), soma_dados_faltantes)).T
tabela_dados_faltantes = tabela_dados_faltantes[tabela_dados_faltantes[:, 1].argsort()[::-1]]

# Exibindo a tabela
print("Coluna | Dados Faltantes")
print("------------------------")
for coluna, dados_faltantes in tabela_dados_faltantes:
    print(f"   {int(coluna)}   |       {int(dados_faltantes)}")
# Out:
# Coluna | Dados Faltantes
# ------------------------
#    34   |       0
#    8   |       0
#    14   |       0
#    13   |       0
#    12   |       0
#    11   |       0
#    10   |       0
#    9   |       0
#    7   |       0
#    16   |       0
#    6   |       0
#    5   |       0
#    4   |       0
#    3   |       0
#    2   |       0
#    1   |       0
#    15   |       0
#    17   |       0
#    33   |       0
#    26   |       0
#    32   |       0
#    31   |       0
#    30   |       0
#    29   |       0
#    28   |       0
#    27   |       0
#    25   |       0
#    18   |       0
#    24   |       0
#    23   |       0
#    22   |       0
#    21   |       0
#    20   |       0
#    19   |       0
#    0   |       0

# %% [markdown]
# - Escrevendo dados padronizados

# %%
scaler = StandardScaler()

df_train_standard = pd.DataFrame(scaler.fit_transform(df_train[colunas_selecionadas+["inadimplente"]]), columns=colunas_selecionadas+["inadimplente"])

X_train_standard = df_train_standard.iloc[:,df_train_standard.columns!='inadimplente'].values #pega todas as colunas selecionadas
y_train_standard = df_train_standard["inadimplente"].iloc[:,].values #pega somente a coluna inadimplente

# conjunto de teste (5000) sem target

df_test_standard = pd.DataFrame(scaler.fit_transform(df_test[colunas_selecionadas]), columns=colunas_selecionadas)

X_test_output_standard = df_test_standard[colunas_selecionadas].iloc[:,:].values

# %%
X_train_standard, X_test_standard, y_train_standard, y_test_standard = train_test_split(
    X_train_standard, 
    y_train_standard.ravel(),
    train_size=0.8,
    shuffle=True,
    random_state=777
    )

# %%
# Função para submeter para o Kaggle

def submissao_kaggle(df_test, y_predict_output, nome_file):
    
    id_solicitante = df_test.loc[:,df_test.columns=='id_solicitante'].values

    id_solicitante = id_solicitante.ravel()
    y_predict_output =  y_predict_output.ravel()

    dict_input = {'id_solicitante': id_solicitante, 'inadimplente': y_predict_output}
    input_classificador = pd.DataFrame(data = dict_input)

    input_classificador.to_csv(nome_file, index = False)

# %% [markdown]
# #### KNN

# %% [markdown]
# ##### Treinando modelo

# %% [markdown]
# - Parâmetros considerados
#     - n_neighbors:
#         - O número de vizinhos.
#     - weights (Função peso usada na predição):
#         - Se “uniform”, então os pesos são uniformes.
#         - Se “distance”, então os pesos são inversosa sua distância.

# %%
def classificadorKNN(X_train, y_train, X_test, y_test):
    results = []
    for k in range(1, 50):

        model = KNeighborsClassifier(n_neighbors=k,weights='uniform')
        model.fit(X_train,y_train)
        y_predict  = model.predict(X_test)

        acuracia = accuracy_score(y_test, y_predict)

        result_uniform = [k, "uniform", acuracia]

        results.append(result_uniform)

        model = KNeighborsClassifier(n_neighbors=k,weights='distance')
        model.fit(X_train,y_train)
        y_predict  = model.predict(X_test)

        acuracia = accuracy_score(y_test, y_predict)

        result_distance = [k, "distance", acuracia]

        results.append(result_distance)

    return [pd.DataFrame(results, columns=["n_neighbors", "weights", "accuracy"]), y_predict]

# %% [markdown]
# - Treinar o modelo KNN com o conjunto de treino sem utilizar medidas padronizadas

# %%
result = classificadorKNN(X_train, y_train, X_test, y_test)

# %% [markdown]
# - Decidindo melhor n_neighbors e melhor weights

# %%
result_sort = result[0].sort_values(by='accuracy', ascending=False)
result_sort
# Out:
#      n_neighbors   weights  accuracy
# 23            12  distance   0.54150
# 35            18  distance   0.54075
# 29            15  distance   0.54025
# 31            16  distance   0.53950
# 25            13  distance   0.53925
# ..           ...       ...       ...
# 196           99   uniform   0.50325
# 190           96   uniform   0.50300
# 174           88   uniform   0.50300
# 192           97   uniform   0.50200
# 182           92   uniform   0.50175
#
# [198 rows x 3 columns]

# %% [markdown]
# - Predição para os dados de teste

# %%
model = KNeighborsClassifier(n_neighbors=12,weights='distance')
model.fit(X_train,y_train)
y_predict_output  = model.predict(X_test_output)
submissao_kaggle(df_test, y_predict_output, "input_classificador_knn_sem_padronizacao.csv")

# %% [markdown]
# - Treinar o modelo KNN com o conjunto de treino utilizando medidas padronizadas

# %%
result = classificadorKNN(X_train_standard, y_train_standard, X_test_standard, y_test_standard)

# %% [markdown]
# - Decidindo melhor n_neighbors e melhor weights

# %%
result_sort = result[0].sort_values(by='accuracy', ascending=False)
result_sort
# Out:
#      n_neighbors   weights  accuracy
# 195           98  distance   0.56150
# 147           74  distance   0.56050
# 197           99  distance   0.56025
# 194           98   uniform   0.55950
# 125           63  distance   0.55875
# ..           ...       ...       ...
# 8              5   uniform   0.52925
# 14             8   uniform   0.52875
# 4              3   uniform   0.52825
# 10             6   uniform   0.52375
# 2              2   uniform   0.51900
#
# [198 rows x 3 columns]

# %% [markdown]
# - Predição para os dados de teste

# %%
model = KNeighborsClassifier(n_neighbors=98,weights='distance')
model.fit(X_train_standard,y_train_standard)
y_predict_output  = model.predict(X_test_output)
submissao_kaggle(df_test, y_predict_output, "input_classificador_knn_com_padronizacao.csv")

# %% [markdown]
# ##### Random Forest

# %% [markdown]
# ##### Treinando modelo

# %% [markdown]
# - Parâmetros considerados
#     - n_estimators:
#         - O número de árvores na floresta.
#     - max_features:
#         - Se “sqrt”, então max_features=sqrt(n_features).
#         - Se “log2”, então max_features=log2(n_features)

# %%
def classificadorRandomForest(X_train, y_train, X_test, y_test):
    results = []
    for k in range(1, 50):

        model = RandomForestClassifier(n_estimators=k,        max_features='sqrt',
        oob_score=True,
        max_depth=None,
        random_state=123
        )
        model.fit(X_train,y_train)
        y_predict  = model.predict(X_test)

        acuracia = accuracy_score(y_test, y_predict)

        result_uniform = [k, "sqrt", acuracia]

        results.append(result_uniform)

        model = RandomForestClassifier(n_estimators=k,        max_features='log2',
        oob_score=True,
        max_depth=None,
        random_state=123
        )
        model.fit(X_train,y_train)
        y_predict  = model.predict(X_test)

        acuracia = accuracy_score(y_test, y_predict)

        result_distance = [k, "log2", acuracia]

        results.append(result_distance)

    return [pd.DataFrame(results, columns=["n_estimators", "max_features", "accuracy"]), y_predict]

# %% [markdown]
# - Treinar o modelo Random Forest com o conjunto de treino sem utilizar medidas padronizadas

# %%
result = classificadorRandomForest(X_train, y_train, X_test, y_test)
# Out:
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(

# %% [markdown]
# - Decidindo melhor n_neighbors e melhor weights

# %%
result_sort = result[0].sort_values(by='accuracy', ascending=False)
result_sort
# Out:
#     n_estimators max_features  accuracy
# 64            33         sqrt   0.57250
# 65            33         log2   0.57250
# 71            36         log2   0.57225
# 70            36         sqrt   0.57225
# 75            38         log2   0.57200
# ..           ...          ...       ...
# 5              3         log2   0.54075
# 1              1         log2   0.53275
# 0              1         sqrt   0.53275
# 3              2         log2   0.52875
# 2              2         sqrt   0.52875
#
# [198 rows x 3 columns]

# %% [markdown]
# - Predição para os dados de teste

# %%
model = RandomForestClassifier(n_estimators=33,        max_features='sqrt',
oob_score=True,
max_depth=None,
random_state=123
)
model.fit(X_train,y_train)
y_predict_output  = model.predict(X_test_output)
submissao_kaggle(df_test, y_predict_output, "input_classificador_randomforest_sem_padronizacao.csv")

# %% [markdown]
# - Treinar o modelo Random Forest com o conjunto de treino utilizando medidadas padronizadas

# %%
result = classificadorRandomForest(X_train_standard, y_train_standard, X_test_standard, y_test_standard)
# Out:
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# c:\Users\amand\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\ensemble\_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(

# %% [markdown]
# - Decidindo melhor n_neighbors e melhor weights

# %%
result_sort = result[0].sort_values(by='accuracy', ascending=False)
result_sort
# Out:
#      n_estimators max_features  accuracy
# 70             36         sqrt   0.57425
# 71             36         log2   0.57425
# 55             28         log2   0.57275
# 54             28         sqrt   0.57275
# 107            54         log2   0.57250
# ..            ...          ...       ...
# 5               3         log2   0.54125
# 1               1         log2   0.53300
# 0               1         sqrt   0.53300
# 3               2         log2   0.53000
# 2               2         sqrt   0.53000
#
# [198 rows x 3 columns]

# %% [markdown]
# - Predição para os dados de teste

# %%
model = RandomForestClassifier(n_estimators=36,        max_features='sqrt',
oob_score=True,
max_depth=None,
random_state=123
)
model.fit(X_train_standard,y_train_standard)
y_predict_output  = model.predict(X_test_output_standard)
submissao_kaggle(df_test, y_predict_output, "input_classificador_randomforest_com_padronizacao.csv")

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Métricas de avaliação

# %% [markdown]
# ### Matriz de Confusão

# %% [markdown]
# ## Conclusão

# %%
submissao_kaggle(df_test, y_predict_output, "teste.csv")
